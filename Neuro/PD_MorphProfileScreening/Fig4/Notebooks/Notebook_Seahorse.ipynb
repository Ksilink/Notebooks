# %%
import pandas as pd
import seaborn as sns

# %%
# Read the CSV file containing the input table
input_file = r"C:\Users\JohannesWilbertz\OneDrive - Ksilink\PD\SNCA_screening_paper\Figures\Fig4\Raw data\Seahorse_data.csv"
df = pd.read_csv(input_file)

# %%
ax = sns.lineplot(data=df, x="Measurement", y="OCR", hue="Exp_cond",)

# %%
# Read the CSV file containing the input table
input_file = r"C:\Users\JohannesWilbertz\OneDrive - Ksilink\PD\SNCA_screening_paper\Figures\Fig4\Raw data\Seahorse_data_normalized.csv"
df = pd.read_csv(input_file)

# %%
ax = sns.lineplot(data=df, x="Measurement", y="OCR", hue="Exp_cond", style="Exp_cond",
    markers=True, dashes=False)
